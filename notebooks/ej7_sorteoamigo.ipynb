# %%
import sys
sys.path.append('../src')
import sorteoamigo7

# %%
sorteoamigo7.sorteo_amigo_invisible()
# Out:
# Sorteo de amigo invisible:
#  Ana → Lucía
#  Pedro → Sofía
#  Lucía → Pedro
#  Mateo → Ana
#  Sofía → Mateo
