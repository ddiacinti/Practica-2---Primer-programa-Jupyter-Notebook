# %%
import sys
sys.path.append('../src')
import email4

# %%
email = input("Ingrese un email: ")
if email4.validar_email(email):
    print("El email es válido.")
else:
    print("El email no es válido.")
# Out:
# El email no es válido.
